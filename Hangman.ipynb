# %% [markdown]
# # HANGMAN

# %%
import tkinter as tk
from tkinter import messagebox, ttk
import random

categories = {
    'animals': ["lion", "tiger", "elephant", "giraffe", "zebra", "cheetah", "leopard", "bear", "wolf", "fox", "rabbit", "deer", "kangaroo", "koala", "panda", "monkey", "gorilla", "chimpanzee", "dolphin", "whale", "shark", "octopus", "penguin", "seal", "walrus", "eagle", "owl", "sparrow", "parrot", "peacock", "crocodile", "alligator", "turtle", "frog", "snake", "lizard", "hamster", "rat", "mouse", "bat", "ant", "bee", "butterfly", "spider", "scorpion", "horse", "cow", "sheep", "goat", "camel"],

    'cities': ["new york", "london", "tokyo", "paris", "berlin", "sydney", "dubai", "rome", "moscow", "toronto", "mumbai", "shanghai", "singapore", "barcelona", "istanbul", "los angeles", "san francisco", "mexico city", "rio de janeiro", "buenos aires", "cairo", "beijing", "hong kong", "seoul", "bangkok", "vienna", "amsterdam", "prague", "dublin", "stockholm", "oslo", "helsinki", "copenhagen", "lisbon", "athens", "cape town", "nairobi", "lagos", "kuala lumpur", "jakarta", "brussels", "zurich", "geneva", "warsaw", "budapest", "manila", "vancouver", "melbourne", "edinburgh", "johannesburg"],

    'colors': ["red", "blue", "green", "yellow", "orange", "purple", "pink", "brown", "black", "white", "gray", "violet", "indigo", "cyan", "magenta", "beige", "turquoise", "teal", "navy", "gold", "silver", "bronze", "lime", "peach", "lavender", "maroon", "crimson", "amber", "chartreuse", "coral", "salmon", "emerald", "azure", "mint", "plum", "ochre", "ruby", "topaz", "ivory", "sapphire", "jade", "pearl", "blush", "apricot", "alabaster", "snow", "sky blue", "forest green", "rose"],

    'countries': ["canada", "mexico", "brazil", "argentina", "uk", "france", "germany", "spain", "italy", "india", "china", "japan", "australia", "south korea", "russia", "south africa", "egypt", "nigeria", "kenya", "colombia", "chile", "peru", "saudi arabia", "iran", "turkey", "israel", "singapore", "new zealand", "sweden", "norway", "finland", "denmark", "belgium", "netherlands", "switzerland", "poland", "portugal", "austria", "greece", "romania", "czech republic", "hungary", "ukraine", "vietnam", "philippines", "malaysia", "thailand", "bangladesh"],

    'fruits': ["apple", "banana", "orange", "mango", "grapes", "pear", "peach", "cherry", "pineapple", "strawberry", "blueberry", "blackberry", "raspberry", "kiwi", "watermelon", "melon", "plum", "apricot", "papaya", "pomegranate", "lemon", "lime", "coconut", "fig", "date", "nectarine", "tangerine", "mandarin", "dragon fruit", "passion fruit", "jackfruit", "guava", "lychee", "longan", "star fruit", "cranberry", "gooseberry", "currant", "persimmon", "breadfruit", "avocado", "cantaloupe", "elderberry", "chikoo", "rhubarb", "soursop", "kiwifruit", "carambola", "satsuma", "blood orange"],

    'movies': ["dilwale dulhania le jayenge", "kabhi khushi kabhie gham", "3 idiots", "titanic", "inception", "the dark knight", "lagaan", "dangal", "taare zameen par", "sholay", "jaws", "the godfather", "forrest gump", "the shawshank redemption", "rocky", "pulp fiction", "memento", "gladiator", "interstellar", "the lion king", "f&f: fast and furious", "mera naam joker", "pakeezah", "mother india", "chakde india", "bajrangi bhaijaan", "kuch kuch hota hai", "gully boy", "dil chahta hai", "piku", "zindagi na milegi dobara", "the godfather part 2", "goodfellas", "scarface", "the silence of the lambs", "veer zaara", "the pursuit of happiness", "the notebook", "hidden figures", "tanu weds manu", "hamari adhuri kahani", "khuda ke liye", "bol", "khamoshi", "dil se", "the social network", "the wolf of wall street", "batman begins", "spider man", "bajirao mastani"],

    'sports': ["soccer", "basketball", "cricket", "rugby", "tennis", "baseball", "volleyball", "hockey", "golf", "swimming", "badminton", "boxing", "wrestling", "mma", "athletics", "cycling", "skateboarding", "skiing", "snowboarding", "table tennis", "football", "karate", "judo", "taekwondo", "fencing", "archery", "sailing", "rowing", "handball", "water polo", "surfing", "gymnastics", "darts", "equestrian", "chess", "squash", "lacrosse", "motor racing", "e-sports", "billiards", "pool", "bowling", "weightlifting", "disc golf", "polo", "water skiing", "rock climbing", "kickboxing"],

    'vegetables': ["carrot", "broccoli", "spinach", "potato", "tomato", "cucumber", "onion", "garlic", "cauliflower", "peas", "corn", "bell pepper", "lettuce", "cabbage", "zucchini", "eggplant", "pumpkin", "sweet potato", "radish", "beetroot", "asparagus", "kale", "brussels sprouts", "chard", "artichoke", "celery", "turnip", "parsnip", "leek", "ginger", "okra", "mushroom", "green beans", "chili", "aubergine", "bamboo shoots", "fennel", "rutabaga", "yam", "mustard greens", "arugula", "watercress", "daikon", "scallion", "bok choy", "endive", "collard greens", "snow peas", "cress", "sweet corn"]
}

def select_random_word(category):
    return random.choice(categories[category]).lower()

class HangmanGUI:
    def __init__(self, master):
        self.master = master
        self.master.title("🎮 Hangman Game")
        self.master.geometry("1100x600")
        self.master.configure(bg="#f4f6f7")

        self.word = ""
        self.guessed_letters = set()
        self.incorrect_guesses = 0
        self.max_incorrect_guesses = 6
        self.game_started = False

        self.create_widgets()

    def create_widgets(self):
        tk.Label(self.master, text="🪢 HANGMAN", font=("Helvetica", 32, "bold"), bg="#f4f6f7", fg="#2e86c1").pack(pady=10)

        frame = tk.Frame(self.master, bg="#f4f6f7")
        frame.pack(pady=5)

        tk.Label(frame, text="Select Category:", font=("Helvetica", 14), bg="#f4f6f7").pack(side="left", padx=10)
        self.category_var = tk.StringVar()
        self.category_box = ttk.Combobox(frame, textvariable=self.category_var, state="readonly", font=("Helvetica", 12))
        self.category_box['values'] = list(categories.keys())
        self.category_box.set("Choose")
        self.category_box.pack(side="left", padx=10)

        tk.Button(self.master, text="Start Game", font=("Helvetica", 12, "bold"), command=self.start_game).pack(pady=10)

        self.word_display = tk.Label(self.master, text="", font=("Courier", 24, "bold"), bg="#f4f6f7", fg="#2c3e50")
        self.word_display.pack(pady=30)

        self.guess_label = tk.Label(self.master, text="Guess a Letter:", font=("Helvetica", 14), bg="#f4f6f7")
        self.letter_entry = tk.Entry(self.master, font=("Helvetica", 16), width=5, justify='center')
        self.submit_button = tk.Button(self.master, text="Guess", font=("Helvetica", 12, "bold"), command=self.guess_letter)

        self.guess_label.pack()
        self.letter_entry.pack(pady=5)
        self.submit_button.pack(pady=5)
        self.disable_guessing()

        self.status_label = tk.Label(self.master, text="", font=("Helvetica", 12), bg="#f4f6f7", fg="#2874A6")
        self.status_label.pack(pady=10)

        self.restart_button = tk.Button(self.master, text="Restart", font=("Helvetica", 12, "bold"), command=self.reset_game, state="disabled")
        self.restart_button.pack(pady=10)

    def enable_guessing(self):
        self.letter_entry.config(state="normal")
        self.submit_button.config(state="normal")

    def disable_guessing(self):
        self.letter_entry.config(state="disabled")
        self.submit_button.config(state="disabled")

    def start_game(self):
        category = self.category_var.get()
        if category not in categories:
            messagebox.showerror("Error", "Please select a valid category.")
            return

        self.word = select_random_word(category)
        self.guessed_letters = set()
        self.incorrect_guesses = 0
        self.status_label.config(text="")
        self.update_display()
        self.restart_button.config(state="disabled")
        self.enable_guessing()
        self.game_started = True

    def update_display(self):
        display = '  '.join([ch if not ch.isalpha() or ch in self.guessed_letters else '_' for ch in self.word])
        self.word_display.config(text=display)

        if all(ch in self.guessed_letters or not ch.isalpha() for ch in self.word):
            self.status_label.config(text=f"🎉 You guessed it! The word was '{self.word}'.")
            self.disable_guessing()
            self.restart_button.config(state="normal")

    def guess_letter(self):
        if not self.game_started:
            return

        guess = self.letter_entry.get().lower().strip()
        self.letter_entry.delete(0, tk.END)

        if len(guess) != 1 or not guess.isalpha():
            self.status_label.config(text="⚠️ Enter a single alphabet letter.")
            return

        if guess in self.guessed_letters:
            self.status_label.config(text=f"⚠️ You already guessed '{guess}'.")
            return

        self.guessed_letters.add(guess)

        if guess in self.word:
            self.status_label.config(text=f"✅ Good guess: '{guess}'")
        else:
            self.incorrect_guesses += 1
            self.status_label.config(
                text=f"❌ Wrong guess: '{guess}' ({self.incorrect_guesses}/{self.max_incorrect_guesses})"
            )

        self.update_display()

        if self.incorrect_guesses >= self.max_incorrect_guesses:
            self.word_display.config(text=self.word)
            self.status_label.config(text=f"💀 Game Over! The word was '{self.word}'.")
            self.disable_guessing()
            self.restart_button.config(state="normal")

    def reset_game(self):
        self.word = ""
        self.word_display.config(text="")
        self.status_label.config(text="")
        self.category_box.set("Choose")
        self.disable_guessing()
        self.restart_button.config(state="disabled")
        self.game_started = False

if __name__ == "__main__":
    root = tk.Tk()
    game = HangmanGUI(root)
    root.mainloop()

# %%
import random

def convert_to_lowercase(categories):
    for category in categories:
        categories[category] = [word.lower() for word in categories[category]]

def select_random_word(category):
    categories = {
        'animals': ["lion", "tiger", "elephant", "giraffe", "zebra", 
    "cheetah", "leopard", "bear", "wolf", "fox", 
    "rabbit", "deer", "kangaroo", "koala", "panda", 
    "monkey", "gorilla", "chimpanzee", "dolphin", "whale", 
    "shark", "octopus", "penguin", "seal", "walrus", 
    "eagle", "owl", "sparrow", "parrot", "peacock", 
    "crocodile", "alligator", "turtle", "frog", "snake", 
    "lizard", "hamster", "rat", "mouse", "bat", 
    "ant", "bee", "butterfly", "spider", "scorpion", 
    "horse", "cow", "sheep", "goat", "camel"],
        
        'cities': ["new york", "london", "tokyo", "paris", "berlin", 
    "sydney", "dubai", "rome", "moscow", "toronto", 
    "mumbai", "shanghai", "singapore", "barcelona", "istanbul", 
    "los angeles", "san francisco", "mexico city", "rio de janeiro", "buenos aires", 
    "cairo", "beijing", "hong kong", "seoul", "bangkok", 
    "vienna", "amsterdam", "prague", "dublin", "stockholm", 
    "oslo", "helsinki", "copenhagen", "lisbon", "athens", 
    "cape town", "nairobi", "lagos", "kuala lumpur", "jakarta", 
    "brussels", "zurich", "geneva", "warsaw", "budapest", 
    "manila", "vancouver", "melbourne", "edinburgh", "johannesburg"],
        
        'colors': ["red", "blue", "green", "yellow", "orange", 
    "purple", "pink", "brown", "black", "white", 
    "gray", "violet", "indigo", "cyan", "magenta", 
    "beige", "turquoise", "teal", "navy", "gold", 
    "silver", "bronze", "lime", "peach", "lavender", 
    "maroon", "crimson", "amber", "chartreuse", "coral", 
    "salmon", "emerald", "azure", "mint", "plum", 
    "ochre", "ruby", "topaz", "ivory", "sapphire", 
    "jade", "pearl", "blush", "apricot", "alabaster", 
    "ivory", "snow", "sky blue", "forest green", "rose"],
        
        'countries': ["canada", "mexico", "brazil", "argentina", 
    "uk", "france", "germany", "spain", "italy", 
    "india", "china", "japan", "australia", "south korea", 
    "russia", "south africa", "egypt", "nigeria", "kenya", 
    "nigeria", "colombia", "chile", "peru", "saudi arabia", 
    "iran", "turkey", "israel", "singapore", "new zealand", 
    "sweden", "norway", "finland", "denmark", "belgium", 
    "netherlands", "switzerland", "poland", "portugal", "austria", 
    "greece", "romania", "czech republic", "hungary", "ukraine", 
    "vietnam", "philippines", "malaysia", "thailand", "bangladesh"],
        
        'fruits': ["apple", "banana", "orange", "mango", "grapes", 
    "pear", "peach", "cherry", "pineapple", "strawberry", 
    "blueberry", "blackberry", "raspberry", "kiwi", "watermelon", 
    "melon", "plum", "apricot", "papaya", "pomegranate", 
    "lemon", "lime", "coconut", "fig", "date", 
    "nectarine", "tangerine", "mandarin", "dragon fruit", "passion fruit", 
    "jackfruit", "guava", "lychee", "longan", "star fruit", 
    "cranberry", "gooseberry", "currant", "persimmon", "breadfruit", 
    "avocado", "cantaloupe", "elderberry", "chikoo", "rhubarb", 
    "soursop", "kiwifruit", "carambola", "satsuma", "blood orange"],
        
        'movies': ["dilwale dulhania le jayenge", "kabhi khushi kabhie gham", "3 idiots", "titanic", "inception", 
    "the dark knight", "lagaan", "dangal", "taare zameen par", "sholay", 
    "jaws", "the godfather", "forrest gump", "the shawshank redemption", "rocky", 
    "pulp fiction", "memento", "gladiator", "interstellar", "the lion king", 
    "f&f: fast and furious", "mera naam joker", "pakeezah", "mother india", "chakde india", 
    "bajrangi bhaijaan", "kuch kuch hota hai", "gully boy", "dil chahta hai", "piku", 
    "zindagi na milegi dobara", "the godfather part 2", "goodfellas", "scarface", "the silence of the lambs", 
    "veer zaara", "the pursuit of happiness", "the notebook", "hidden figures", "tanu weds manu", 
    "hamari adhuri kahani", "khuda ke liye", "bol", "khamoshi", "dil se", 
    "the social network", "the wolf of wall street", "batman begins", "spider man", "bajirao mastani"],
        
        'sports': ["soccer", "basketball", "cricket", "rugby", "tennis", 
    "baseball", "volleyball", "hockey", "golf", "swimming", 
    "badminton", "boxing", "wrestling", "mma", "athletics", 
    "cycling", "skateboarding", "skiing", "snowboarding", "table tennis", 
    "football", "karate", "judo", "taekwondo", "fencing", 
    "archery", "sailing", "rowing", "handball", "water polo", 
    "surfing", "gymnastics", "darts", "equestrian", "chess", 
    "squash", "lacrosse", "motor racing", "e-sports", "billiards", 
    "pool", "bowling", "weightlifting", "disc golf", "polo", 
    "cricket", "lacrosse", "water skiing", "rock climbing", "kickboxing"],
        
        'vegetables': ["carrot", "broccoli", "spinach", "potato", "tomato", 
    "cucumber", "onion", "garlic", "cauliflower", "peas", 
    "corn", "bell pepper", "lettuce", "cabbage", "zucchini", 
    "eggplant", "pumpkin", "sweet potato", "radish", "beetroot", 
    "asparagus", "kale", "brussels sprouts", "chard", "artichoke", 
    "celery", "turnip", "parsnip", "leek", "ginger", 
    "okra", "mushroom", "green beans", "chili", "aubergine", 
    "bamboo shoots", "fennel", "rutabaga", "yam", "mustard greens", 
    "arugula", "watercress", "daikon", "scallion", "bok choy", 
    "endive", "collard greens", "snow peas", "cress", "sweet corn"]
    }
    
    if category not in categories:
        raise ValueError("Category not found.")
    return random.choice(categories[category])

def display_word(word, guessed_letters):
    return ' '.join([letter if letter in guessed_letters else '_' for letter in word])

def hangman():
    categories = {
        'animals': ["lion", "tiger", "elephant", "giraffe", "zebra", 
    "cheetah", "leopard", "bear", "wolf", "fox", 
    "rabbit", "deer", "kangaroo", "koala", "panda", 
    "monkey", "gorilla", "chimpanzee", "dolphin", "whale", 
    "shark", "octopus", "penguin", "seal", "walrus", 
    "eagle", "owl", "sparrow", "parrot", "peacock", 
    "crocodile", "alligator", "turtle", "frog", "snake", 
    "lizard", "hamster", "rat", "mouse", "bat", 
    "ant", "bee", "butterfly", "spider", "scorpion", 
    "horse", "cow", "sheep", "goat", "camel"],
        
        'cities': ["new york", "london", "tokyo", "paris", "berlin", 
    "sydney", "dubai", "rome", "moscow", "toronto", 
    "mumbai", "shanghai", "singapore", "barcelona", "istanbul", 
    "los angeles", "san francisco", "mexico city", "rio de janeiro", "buenos aires", 
    "cairo", "beijing", "hong kong", "seoul", "bangkok", 
    "vienna", "amsterdam", "prague", "dublin", "stockholm", 
    "oslo", "helsinki", "copenhagen", "lisbon", "athens", 
    "cape town", "nairobi", "lagos", "kuala lumpur", "jakarta", 
    "brussels", "zurich", "geneva", "warsaw", "budapest", 
    "manila", "vancouver", "melbourne", "edinburgh", "johannesburg"],
        
        'colors': ["red", "blue", "green", "yellow", "orange", 
    "purple", "pink", "brown", "black", "white", 
    "gray", "violet", "indigo", "cyan", "magenta", 
    "beige", "turquoise", "teal", "navy", "gold", 
    "silver", "bronze", "lime", "peach", "lavender", 
    "maroon", "crimson", "amber", "chartreuse", "coral", 
    "salmon", "emerald", "azure", "mint", "plum", 
    "ochre", "ruby", "topaz", "ivory", "sapphire", 
    "jade", "pearl", "blush", "apricot", "alabaster", 
    "ivory", "snow", "sky blue", "forest green", "rose"],
        
        'countries': ["canada", "mexico", "brazil", "argentina", 
    "uk", "france", "germany", "spain", "italy", 
    "india", "china", "japan", "australia", "south korea", 
    "russia", "south africa", "egypt", "nigeria", "kenya", 
    "nigeria", "colombia", "chile", "peru", "saudi arabia", 
    "iran", "turkey", "israel", "singapore", "new zealand", 
    "sweden", "norway", "finland", "denmark", "belgium", 
    "netherlands", "switzerland", "poland", "portugal", "austria", 
    "greece", "romania", "czech republic", "hungary", "ukraine", 
    "vietnam", "philippines", "malaysia", "thailand", "bangladesh"],
        
        'fruits': ["apple", "banana", "orange", "mango", "grapes", 
    "pear", "peach", "cherry", "pineapple", "strawberry", 
    "blueberry", "blackberry", "raspberry", "kiwi", "watermelon", 
    "melon", "plum", "apricot", "papaya", "pomegranate", 
    "lemon", "lime", "coconut", "fig", "date", 
    "nectarine", "tangerine", "mandarin", "dragon fruit", "passion fruit", 
    "jackfruit", "guava", "lychee", "longan", "star fruit", 
    "cranberry", "gooseberry", "currant", "persimmon", "breadfruit", 
    "avocado", "cantaloupe", "elderberry", "chikoo", "rhubarb", 
    "soursop", "kiwifruit", "carambola", "satsuma"],
        
        'movies': ["dilwale dulhania le jayenge", "kabhi khushi kabhie gham", "3 idiots", "titanic", "inception", 
    "the dark knight", "lagaan", "dangal", "taare zameen par", "sholay", 
    "jaws", "the godfather", "forrest gump", "the shawshank redemption", "rocky", 
    "pulp fiction", "memento", "gladiator", "interstellar", "the lion king", 
    "f&f: fast and furious", "mera naam joker", "pakeezah", "mother india", "chakde india", 
    "bajrangi bhaijaan", "kuch kuch hota hai", "gully boy", "dil chahta hai", "piku", 
    "zindagi na milegi dobara", "the godfather part 2", "goodfellas", "scarface", "the silence of the lambs", 
    "veer zaara", "the pursuit of happiness", "the notebook", "hidden figures", "tanu weds manu", 
    "hamari adhuri kahani", "khuda ke liye", "bol", "khamoshi", "dil se", 
    "the social network", "the wolf of wall street", "batman begins", "spider man", "bajirao mastani"],
        
        'sports': ["soccer", "basketball", "cricket", "rugby", "tennis", 
    "baseball", "volleyball", "hockey", "golf", "swimming", 
    "badminton", "boxing", "wrestling", "mma", "athletics", 
    "cycling", "skateboarding", "skiing", "snowboarding", "table tennis", 
    "football", "karate", "judo", "taekwondo", "fencing", 
    "archery", "sailing", "rowing", "handball", "water polo", 
    "surfing", "gymnastics", "darts", "equestrian", "chess", 
    "squash", "lacrosse", "motor racing", "e-sports", "billiards", 
    "pool", "bowling", "weightlifting", "disc golf", "polo", 
    "cricket", "lacrosse", "water skiing", "rock climbing", "kickboxing"],
        
        'vegetables': ["carrot", "broccoli", "spinach", "potato", "tomato", 
    "cucumber", "onion", "garlic", "cauliflower", "peas", 
    "corn", "bell pepper", "lettuce", "cabbage", "zucchini", 
    "eggplant", "pumpkin", "sweet potato", "radish", "beetroot", 
    "asparagus", "kale", "brussels sprouts", "chard", "artichoke", 
    "celery", "turnip", "parsnip", "leek", "ginger", 
    "okra", "mushroom", "green beans", "chili", "aubergine", 
    "bamboo shoots", "fennel", "rutabaga", "yam", "mustard greens", 
    "arugula", "watercress", "daikon", "scallion", "bok choy", 
    "endive", "collard greens", "snow peas", "cress", "sweet corn"]
    }

    sentence = "Welcome to Hangman!"
    bold_sentence = "\033[1m" + sentence.upper() + "\033[0m"
    print(bold_sentence)

    print("Please choose a category:")
    
    for idx, category in enumerate(categories.keys(), start=1):
        print(f"{idx}. {category}")
    
    try:
        choice = int(input("Enter the number of the category: "))
        if choice < 1 or choice > len(categories):
            print("Invalid choice. Please choose a number from the list.")
            return
        category = list(categories.keys())[choice - 1]
    except ValueError:
        print("Invalid input. Please enter a number.")
        return

    word = select_random_word(category)
    guessed_letters = set()
    incorrect_guesses = 0
    max_incorrect_guesses = 6

    while incorrect_guesses < max_incorrect_guesses:
        current_display = display_word(word, guessed_letters)
        print(f"\nWord: {current_display}")
        print(f"Incorrect guesses: {incorrect_guesses}/{max_incorrect_guesses}")

        if '_' not in current_display:
            print(f"\nCongratulations! You guessed the word '{word}'!")
            break

        guess = input("Guess a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Please guess a single letter.")
            continue

        if guess in guessed_letters:
            print("You have already guessed that letter.")
            continue

        guessed_letters.add(guess)

        if guess in word:
            print(f"Good guess! '{guess}' is in the word.")
        else:
            print(f"Sorry, '{guess}' is not in the word.")
            incorrect_guesses += 1

    if incorrect_guesses == max_incorrect_guesses:
        print(f"\nGame over! The word was '{word}'.")

if __name__ == "__main__":
    hangman()
# Out:
# WELCOME TO HANGMAN!
# Please choose a category:
# 1. animals
# 2. cities
# 3. colors
# 4. countries
# 5. fruits
# 6. movies
# 7. sports
# 8. vegetables
# Enter the number of the category:  4
# Word: _ _ _ _ _ _
# Incorrect guesses: 0/6
# Guess a letter:  a
# Sorry, 'a' is not in the word.
#
# Word: _ _ _ _ _ _
# Incorrect guesses: 1/6
# Guess a letter:  e
# Good guess! 'e' is in the word.
#
# Word: _ e _ _ _ _
# Incorrect guesses: 1/6
# Guess a letter:  o
# Good guess! 'o' is in the word.
#
# Word: _ e _ _ _ o
# Incorrect guesses: 1/6
# Guess a letter:  s
# Sorry, 's' is not in the word.
#
# Word: _ e _ _ _ o
# Incorrect guesses: 2/6
# Guess a letter:  i
# Good guess! 'i' is in the word.
#
# Word: _ e _ i _ o
# Incorrect guesses: 2/6
# Guess a letter:  t
# Sorry, 't' is not in the word.
#
# Word: _ e _ i _ o
# Incorrect guesses: 3/6
# Guess a letter:  h
# Sorry, 'h' is not in the word.
#
# Word: _ e _ i _ o
# Incorrect guesses: 4/6
# Guess a letter:  m
# Good guess! 'm' is in the word.
#
# Word: m e _ i _ o
# Incorrect guesses: 4/6
# Guess a letter:  n
# Sorry, 'n' is not in the word.
#
# Word: m e _ i _ o
# Incorrect guesses: 5/6
# Guess a letter:  x
# Good guess! 'x' is in the word.
#
# Word: m e x i _ o
# Incorrect guesses: 5/6
# Guess a letter:  c
# Good guess! 'c' is in the word.
#
# Word: m e x i c o
# Incorrect guesses: 5/6
#
# Congratulations! You guessed the word 'mexico'!
